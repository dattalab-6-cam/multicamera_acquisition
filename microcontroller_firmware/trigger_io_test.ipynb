# %%
from multicamera_acquisition.interfaces.microcontroller import Microcontroller

import logging
logger = logging.getLogger()
logger.setLevel(logging.INFO)

# %%
microcontroller = Microcontroller(basename='foo')

# %%
microcontroller.open_serial_connection(port='/dev/tty.usbmodem127633701')
#microcontroller.open_serial_connection()
# Out:
# INFO:root:Fount ready microcontroller on port: /dev/tty.usbmodem127633701

# %%
microcontroller.start_acquisition(10)

# %%
finished = False
while not finished:
    finished = microcontroller.check_for_input()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 3
#       1 finished = False
#       2 while not finished:
# ----> 3     finished = microcontroller.check_for_input()
#
# File ~/Dropbox (HMS)/caleb weinreb/PROJECTS/MOUSE_SURVEILANCE/24_1_2_6plus2_rig_dev/multicamera_acquisition/multicamera_acquisition/interfaces/microcontroller.py:667, in Microcontroller.check_for_input(self)
#     665         self.trigger_data_file.write(f"{time},{pin},{state}\n")
#     666     else:
# --> 667         raise RuntimeError(f"Unexpected message from microcontroller: {msg}")
#     668 return False
#
# RuntimeError: Unexpected message from microcontroller: b'F\n'

# %%
microcontroller.close()
